# %%
import numpy as np
from airfoil_env import AirfoilControlEnv

# %%
env = AirfoilControlEnv(model_path="best_weights.keras")
print(env.observation_space.nvec, env.action_space.n)
# Out:
# [ 14 250] 204

# %%
policy_probs = np.full((env.observation_space.nvec[0], env.observation_space.nvec[1], env.action_space.n), 0.25)
# print(policy_probs)

# %%
def policy(state: tuple):
    return policy_probs[state]

# %%
action_probabilities = policy((0,0))
for action, prob in zip(range(204), action_probabilities):
    print(f"Probability of taking action {action}: {prob}")
# Out:
# Probability of taking action 0: 0.25
# Probability of taking action 1: 0.25
# Probability of taking action 2: 0.25
# Probability of taking action 3: 0.25
# Probability of taking action 4: 0.25
# Probability of taking action 5: 0.25
# Probability of taking action 6: 0.25
# Probability of taking action 7: 0.25
# Probability of taking action 8: 0.25
# Probability of taking action 9: 0.25
# Probability of taking action 10: 0.25
# Probability of taking action 11: 0.25
# Probability of taking action 12: 0.25
# Probability of taking action 13: 0.25
# Probability of taking action 14: 0.25
# Probability of taking action 15: 0.25
# Probability of taking action 16: 0.25
# Probability of taking action 17: 0.25
# Probability of taking action 18: 0.25
# Probability of taking action 19: 0.25
# Probability of taking action 20: 0.25
# Probability of taking action 21: 0.25
# Probability of taking action 22: 0.25
# Probability of taking action 23: 0.25
# Probability of taking action 24: 0.25
# Probability of taking action 25: 0.25
# Probability of taking action 26: 0.25
# Probability of taking action 27: 0.25
# Probability of taking action 28: 0.25
# Probability of taking action 29: 0.25
# Probability of taking action 30: 0.25
# Probability of taking action 31: 0.25
# Probability of taking action 32: 0.25
# Probability of taking action 33: 0.25
# Probability of taking action 34: 0.25
# Probability of taking action 35: 0.25
# Probability of taking action 36: 0.25
# Probability of taking action 37: 0.25
# Probability of taking action 38: 0.25
# Probability of taking action 39: 0.25
# Probability of taking action 40: 0.25
# Probability of taking action 41: 0.25
# Probability of taking action 42: 0.25
# Probability of taking action 43: 0.25
# Probability of taking action 44: 0.25
# Probability of taking action 45: 0.25
# Probability of taking action 46: 0.25
# Probability of taking action 47: 0.25
# Probability of taking action 48: 0.25
# Probability of taking action 49: 0.25
# Probability of taking action 50: 0.25
# Probability of taking action 51: 0.25
# Probability of taking action 52: 0.25
# Probability of taking action 53: 0.25
# Probability of taking action 54: 0.25
# Probability of taking action 55: 0.25
# Probability of taking action 56: 0.25
# Probability of taking action 57: 0.25
# Probability of taking action 58: 0.25
# Probability of taking action 59: 0.25
# Probability of taking action 60: 0.25
# Probability of taking action 61: 0.25
# Probability of taking action 62: 0.25
# Probability of taking action 63: 0.25
# Probability of taking action 64: 0.25
# Probability of taking action 146: 0.25
# Probability of taking action 147: 0.25
# Probability of taking action 148: 0.25
# Probability of taking action 149: 0.25
# Probability of taking action 150: 0.25
# Probability of taking action 151: 0.25
# Probability of taking action 152: 0.25
# Probability of taking action 153: 0.25
# Probability of taking action 154: 0.25
# Probability of taking action 155: 0.25
# Probability of taking action 156: 0.25
# Probability of taking action 157: 0.25
# Probability of taking action 158: 0.25
# Probability of taking action 159: 0.25
# Probability of taking action 160: 0.25
# Probability of taking action 161: 0.25
# Probability of taking action 162: 0.25
# Probability of taking action 163: 0.25
# Probability of taking action 164: 0.25
# Probability of taking action 165: 0.25
# Probability of taking action 166: 0.25
# Probability of taking action 167: 0.25
# Probability of taking action 168: 0.25
# Probability of taking action 169: 0.25
# Probability of taking action 170: 0.25
# Probability of taking action 171: 0.25
# Probability of taking action 172: 0.25
# Probability of taking action 173: 0.25
# Probability of taking action 174: 0.25
# Probability of taking action 175: 0.25
# Probability of taking action 176: 0.25
# Probability of taking action 177: 0.25
# Probability of taking action 178: 0.25
# Probability of taking action 179: 0.25
# Probability of taking action 180: 0.25
# Probability of taking action 181: 0.25
# Probability of taking action 182: 0.25
# Probability of taking action 183: 0.25
# Probability of taking action 184: 0.25
# Probability of taking action 185: 0.25
# Probability of taking action 186: 0.25
# Probability of taking action 187: 0.25
# Probability of taking action 188: 0.25
# Probability of taking action 189: 0.25
# Probability of taking action 190: 0.25
# Probability of taking action 191: 0.25
# Probability of taking action 192: 0.25
# Probability of taking action 193: 0.25
# Probability of taking action 194: 0.25
# Probability of taking action 195: 0.25
# Probability of taking action 196: 0.25
# Probability of taking action 197: 0.25
# Probability of taking action 198: 0.25
# Probability of taking action 199: 0.25
# Probability of taking action 200: 0.25
# Probability of taking action 201: 0.25
# Probability of taking action 202: 0.25
# Probability of taking action 203: 0.25

# %%
state_values = np.zeros((env.observation_space.nvec[0], env.observation_space.nvec[1]))
# print(state_values)

# %%
def value_iteration(policy_probs, state_values):
    
    for row in range(14):
        for col in range(250):
            # old_value = state_values[(row, col)]
            action_probs = None
            max_qsa = float('-inf')

            for action in range(204):
                state, reward, _, _ = env.step((row, col), action)
                qsa = reward
                if qsa > max_qsa:
                    max_qsa = qsa
                    action_probs = np.zeros(204)
                    action_probs[action] = 1.

            state_values[(row, col)] = max_qsa
            policy_probs[(row, col)] = action_probs
    
    return policy_probs, state_values

# %%
# Initialize environment
env = AirfoilControlEnv(model_path="best_weights.keras")

# Perform Value Iteration
optimal_policy, value_function = value_iteration(env)

# Save the optimal policy
np.save("optimal_policy.npy", optimal_policy)
